# %% [markdown]
# <a href="https://colab.research.google.com/github/NaitikGandhi/My-programs-/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import numpy as np
import json
import random, string
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import requests
import requests, zipfile

#the url and auth_value from the website 
url = 'https://api.zindi.africa/v1/competitions/bloodsai-blood-spectroscopy-classification-challenge/files/OrginalData.zip'
myobj = {'auth_token': 'jPCH8hKtW52qz1j345J1n6v1'} #use your own

x = requests.post(url, data = myobj,stream=True)
target_path = 'OriginalData.zip'

handle = open(target_path, "wb")
for chunk in x.iter_content(chunk_size=512):
    if chunk:  # filter out keep-alive new chunks
        handle.write(chunk)
handle.close()

# !unzip -qq /content/OriginalData.zip

# %%
#maindir = "data/OriginalData" # Directory with your files
traincsv = "/content/Train.csv"
testcsv = "/content/Test.csv"

# %%
train = pd.read_csv(traincsv)
train.head()
# Out:
#     Reading_ID  absorbance0  ...  hemoglobin(hgb)_human  cholesterol_ldl_human
# 0  ID_3SSHI56C     0.479669  ...                     ok                     ok
# 1  ID_599OOLZA     0.471537  ...                   high                   high
# 2  ID_MVJGPQ75     0.444998  ...                     ok                   high
# 3  ID_CK6RF8YV     0.513434  ...                     ok                   high
# 4  ID_82N6QE6I     0.510485  ...                     ok                   high
#
# [5 rows x 176 columns]

# %%
ldl = train

# %%
ldl = ldl.drop(['hemoglobin(hgb)_human','hdl_cholesterol_human'],axis=1)

# %%
ldl.sort_values(by=['cholesterol_ldl_human'])
# Out:
#         Reading_ID  absorbance0  ...  humidity  cholesterol_ldl_human
# 13139  ID_9R5ZR9NX     0.498372  ...     26.30                   high
# 4959   ID_0T6DZ9V5     0.536341  ...     30.87                   high
# 4958   ID_FAUNNNM1     0.644208  ...     22.43                   high
# 4957   ID_6G9C86JD     0.460662  ...     29.45                   high
# 4956   ID_HZUATH8K     0.482617  ...     40.14                   high
# ...            ...          ...  ...       ...                    ...
# 5662   ID_DIBGIPGS     0.468387  ...     23.92                     ok
# 5663   ID_2T3Q1CI9     0.540473  ...     29.73                     ok
# 5666   ID_H599BC9T     0.550188  ...     30.27                     ok
# 5641   ID_UAUSHPTC     0.442313  ...     25.67                     ok
# 6569   ID_CJKAV2BT     0.512075  ...     21.12                     ok
#
# [13140 rows x 174 columns]

# %%
ldl.iloc[13139].iloc[1:171].plot()

# %%
ldl.iloc[9389].iloc[1:171].plot()

# %%
ldl.iloc[3666].iloc[1:171].plot()

# %%
ldl.iloc[9384].iloc[1:171].plot()

# %%
ldl.iloc[9383].iloc[1:171].plot()

# %%
ldl_filtered = ldl[ldl['cholesterol_ldl_human'] == 'ok']

# %%
ldl_filtered.head(15)
# Out:
#      Reading_ID  absorbance0  ...  humidity  cholesterol_ldl_human
# 0   ID_3SSHI56C     0.479669  ...     34.01                     ok
# 5   ID_3LCCBJVO     0.547021  ...     18.85                     ok
# 10  ID_T1DP1ZHA     0.533322  ...     20.83                     ok
# 15  ID_H0QSY05G     0.542999  ...     29.26                     ok
# 17  ID_PM6IMECB     0.505570  ...     24.37                     ok
# 18  ID_MK2MX4L8     0.640017  ...     23.30                     ok
# 19  ID_RFDE66W9     0.507012  ...     27.70                     ok
# 20  ID_3DGBNTWV     0.501692  ...     28.54                     ok
# 21  ID_EOQL1GEK     0.470724  ...     29.81                     ok
# 23  ID_A132AJYK     0.521308  ...     25.52                     ok
# 24  ID_RP4R33FB     0.508980  ...     45.74                     ok
# 26  ID_7DFPF27X     0.515871  ...     44.26                     ok
# 29  ID_AK0Z7VD5     0.532263  ...     32.75                     ok
# ...

# %%
ldl_filtered.iloc[0].iloc[1:171].plot()

# %%
ldl_filtered.iloc[1].iloc[1:171].plot()

# %%
ldl_filtered.iloc[2].iloc[1:171].plot()

# %%
ldl_filtered.iloc[4].iloc[1:171].plot()

# %%
ldl_filtered.iloc[6].iloc[1:171].plot()

# %%
ldl_filtered.iloc[7].iloc[1:171].plot()

# %%
ldl_filtered.iloc[9].iloc[1:171].plot()

# %%
ldl_filteredlow =ldl[ldl['cholesterol_ldl_human'] == 'low']

# %%
ldl_filteredlow.head(15)
# Out:
#       Reading_ID  absorbance0  ...  humidity  cholesterol_ldl_human
# 51   ID_3TYJ8T3O     0.520874  ...     28.60                    low
# 56   ID_TYINFDTU     0.518821  ...     28.67                    low
# 114  ID_7BBJVE75     0.512399  ...     28.57                    low
# 174  ID_234ME8N3     0.514128  ...     34.31                    low
# 192  ID_2CL853WU     0.514278  ...     34.31                    low
# 203  ID_J9Z9G7BC     0.494265  ...     23.73                    low
# 219  ID_IWVZHSKS     0.524161  ...     31.04                    low
# 250  ID_BY1NLEFH     0.525387  ...     21.91                    low
# 272  ID_DGE4XC7F     0.513231  ...     26.20                    low
# 284  ID_CF5O620K     0.487470  ...     24.24                    low
# 296  ID_C870IC6Y     0.536191  ...     21.83                    low
# 327  ID_T2NZNYHK     0.527160  ...     21.55                    low
# 328  ID_BRD2RTK2     0.563594  ...     41.62                    low
# ...

# %%
ldl_filteredlow.iloc[3].iloc[1:171].plot()

# %%
ldl_filteredlow.iloc[5].iloc[1:171].plot()
